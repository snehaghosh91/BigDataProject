# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/crimes_by_BRONX_per_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "b--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.title("Crimes by Year in Bronx")
plt.show()

# %%
data = pd.read_csv('data/crimes_by_BROOKLYN_per_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "g--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number Of Crimes")
plt.title("Crimes by Year in Brooklyn")
plt.show()

# %%
data = pd.read_csv('data/crimes_by_MANHATTAN_per_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number Of Crimes")
plt.title("Crimes by Year in Manhattan")
plt.show()

# %%
data = pd.read_csv('data/crimes_by_QUEENS_per_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "y--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number Of Crimes")
plt.title("Crimes by Year in Queens")
plt.show()

# %%
data = pd.read_csv('data/crimes_by_STATENISLAND_per_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "o--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number Of Crimes")
plt.title("Crimes by Year in Staten Island")
plt.show()
