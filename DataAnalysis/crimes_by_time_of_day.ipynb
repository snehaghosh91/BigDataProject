# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data/crimes_by_time.csv', header=None)

# %%
plt.bar(data[0], data[1], color='red')
plt.xlabel("Time of Day")
plt.ylabel("Number of Crimes")
plt.title("Crimes by Time of Day")
plt.show()
