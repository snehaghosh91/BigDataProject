# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/crimes_by_year.csv', header=None)

# %%
plt.plot(data[0], data[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.title("Crimes by Year")
plt.show()
